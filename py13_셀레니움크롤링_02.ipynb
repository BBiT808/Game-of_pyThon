# %%
### 유성쌤 20250411 수업 계속 !!!!! 셀레니움 크롤링을 지도 위에 표시해본대~~

# %%
#!pip install folium

# %%
import pandas as pd
import folium
file_path = './data ref/starbucks_20250411123612.csv'
data = pd.read_csv(file_path)
data = data[['이름','위도','경도','주소','타입']]
data.head()
# Out:
#         이름         위도          경도         주소             타입
# 0  금정남산동DT  35.262179  129.091325  부산광역시 금정구  pin_generalDT
# 1   금정구청DT  35.238814  129.092986  부산광역시 금정구  pin_generalDT
# 2   온천장역DT  35.224006  129.086560  부산광역시 금정구  pin_generalDT
# 3    부산대정문  35.232122  129.084496  부산광역시 금정구    pin_general
# 4     부산대역  35.230522  129.088694  부산광역시 금정구    pin_general

# %%
fixdata = data[['이름','위도','경도']]
fixdata.head()
# Out:
#         이름         위도          경도
# 0  금정남산동DT  35.262179  129.091325
# 1   금정구청DT  35.238814  129.092986
# 2   온천장역DT  35.224006  129.086560
# 3    부산대정문  35.232122  129.084496
# 4     부산대역  35.230522  129.088694

# %%
coordinates = data[['위도','경도']].to_numpy()
place= fixdata['이름'].to_numpy()

# 중심좌표 설정(기본위치)
center_lat, center_lon = 35.17574571, 129.0817409

# 지도 생성 !!
m = folium.Map(location=[center_lat, center_lon], zoom_start=12 )
store_type = data['타입']


#lat, lon = coordinates[0]
#print(lat, lon)



for i, (lat, lon) in enumerate(coordinates):
    folium.CircleMarker(
        location=[lat, lon],
        radius = 10,
        color = "skyblue",
        fill = True,
        fill_color = "pink",
        fill_opacity = 0.5,
        tooltip = place[i]
    ).add_to(m) # 지도 생성 후 원을 그리고 지도에 붙이기 !!! ^0^
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
coordinates = data[['위도','경도']].to_numpy()
place= fixdata['이름'].to_numpy()

# 중심좌표 설정(기본위치)
center_lat, center_lon = 35.17574571, 129.0817409

# 지도 생성 !!
m = folium.Map(location=[center_lat, center_lon], zoom_start=12 )
store_type = data['타입']

for i, (lat, lon) in enumerate(coordinates):
    if store_type[i] == "pin_generalDT":
        ccolor = "lightgreen"
        fcolor = "orange"
    elif store_type[i] == "pin_general":
        ccolor = "pink"
        fcolor = "yellow"
    else:
        ccolor = "purple"
        fcolor = "skyblue"

        
    # folium.CircleMarker(
    #     location=[lat, lon],
    #     radious = 15,
    #     color = ccolor,
    #     fill = True,
    #     fill_color = fcolor,
    #     fill_opacity = 0.6,
    #     tooltip = place[i]
    # ).add_to(m) # 지도 생성 후 원을 그리고 지도에 붙이기 !!! ^0^

    folium.Marker(
        location=[lat, lon],
        tooltip = place[i], # 각 지점 이름이 마커 위에 표시된대 !!! ^_^
        icon=folium.Icon(color = 'beige', icon = 'star', prefix ='fa')

        # color = ['gray', 'black', 'blue', 'lightred', 'lightgreen', 'orange', 'darkred', 'beige', 'cadetblue', 'darkpurple', 
        # 'lightgray', 'green', 'darkgreen', 'purple', 'darkblue', 'pink', 'red', 'lightblue', 'white']
        # radious = 15,
        # color = ccolor,
        # fill = True,
        # fill_color = fcolor,
        # fill_opacity = 0.6,
        
    ).add_to(m) # 지도 생성 후 원을 그리고 지도에 붙이기 !!! ^0^
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
coordinates = data[['위도','경도']].to_numpy()
place= fixdata['이름'].to_numpy()

# 중심좌표 설정(기본위치)
center_lat, center_lon = 35.17574571, 129.0817409

# 지도 생성 !!
m = folium.Map(location=[center_lat, center_lon], zoom_start=12 )
store_type = data['타입']

for i, (lat, lon) in enumerate(coordinates):
    if store_type[i] == "pin_generalDT":
        ccolor = "lightgreen"
        fcolor = "orange"
    elif store_type[i] == "pin_general":
        ccolor = "pink"
        fcolor = "yellow"
    else:
        ccolor = "purple"
        fcolor = "skyblue"

   # 지도 생성 후 지도 위에 똥그라미 표시 ~~ ^0^
    folium.CircleMarker(
        location=[lat, lon],
        radious = 15,
        color = ccolor,
        fill = True,
        fill_color = fcolor,
        fill_opacity = 0.6,
        tooltip = place[i]
    ).add_to(m) 

    # 지도 위에 이름을 표시 !! ㅇ0ㅇ !!
   folium.Marker(
        location = [lat + 0.001, lon],
        icon = folium.DivIcon(f'<div style="font-size: 9px; color:black; background-color: white; width:50px; white-space: nowrap;overflow:hidden; text-overflow: ellipsis; opacity:0.7; border-radious:5px">{place[i]}</div>')
        #icon = folium.DivIcon(f'{place[i]}')
    ).add_to(m)
m
 
# f'<div style="font-size: 9px; color:black; background-color: white; width:50px; white-space: nowrap;overflow:hidden; text-overflow: ellipsis; opacity:0.7; border-radious:5px">{place[i]}</div>'
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
## 한미락 식단표 긁어오기 !!!

# %%
# 크롬이라는 프로그램의 운전자는 chromediver, 그리고 그 지시는 selenium이 하는 거야~~
from selenium import webdriver
# from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options  import Options
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from datetime import datetime
from bs4 import BeautifulSoup as bs
import pandas as pd
import time

# %%
# Chrome 옵션 설정
options = Options()
options.binary_location = ".//chrome-win64//chrome.exe"
options.add_argument("--no-sandbox") # sandbox 설정
options.add_argument("--disable-dev-shm-usage") # 공유 메모리 설정
options.add_argument("--window-size=1920,1080") # 화면 크키 설정, 반응형 웹 디비
#options.add_argument("--disable-gpu") # GPU 비활성화!!

# ChromeDriver 설정
service = Service("chromedriver.exe")
driver = webdriver.Chrome(service=service, options=options)
driver.get("https://www.pknu.ac.kr/main/399")
print(driver.title)

# 요소찾기
hover_element = driver.find_element(By.CSS_SELECTOR, "#subCont > table > tbody > tr:nth-child(1) > td.bdlTitle > a")
#menu_option = driver.find_element(By.CSS_SELECTOR, "#gnb > div > nav > div > ul > li.gnb_nav03 > div > div > div > ul:nth-child(1) > li.gnb_sub_ttl > a")


# 마우스 호버 액션 ; 마우스를 올린 것처럼 실행 됨 ㅇ0ㅇ
actions = ActionChains(driver)
actions.move_to_element(hover_element).perform()

# # 약간의 시간을 기다린 후 클릭!
# time.sleep(1)
# menu_option.click()
# time.sleep(5)
# print("매장 검색 중")

# # 입력창 선택 후 검색
# driver.find_element(By.CSS_SELECTOR,"#container > div > form > fieldset > div > section > article.find_store_cont > article > header.loca_search > h3 > a").click()
#  # 지역검색을 선택 !!
# print("지역 검색 중")
# time.sleep(1)
# driver.find_element(By.CSS_SELECTOR,"#container > div > form > fieldset > div > section > article.find_store_cont > article > article:nth-child(4) > div.loca_step1 > div.loca_step1_cont > ul > li:nth-child(6) > a").click()
#  # 부산을 선택 !
# print("부산 검색 중")
# time.sleep(1)
# driver.find_element(By.CSS_SELECTOR,"#mCSB_2_container > ul > li:nth-child(1) > a").click() # '부산'을 클릭!
# print("부산 전체 로드 중 . . ")
# time.sleep(1)
# html = driver.page_source
# print(html)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Chrome 옵션 설정
# ----> 2 options = Options()
#       3 options.binary_location = ".//chrome-win64//chrome.exe"
#       4 options.add_argument("--no-sandbox") # sandbox 설정
#
# NameError: name 'Options' is not defined

# %%
#subCont > table > tbody > tr:nth-child(1) > td.bdlTitle > a
