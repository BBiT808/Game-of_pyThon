# %%
# 20250227 수업!!!!!!! 헉 ??? 19번째 수업이라고 ?????? 진짜예요 ?????

# %%
# !pip install wordcloud

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# 샘플 텍스트
text = """
Quotes about Python
Python is used successfully in thousands of real-world business applications around the world, including many large and mission critical systems. Here are some quotes from happy Python users:
YouTube.com
"Python is fast enough for our site and allows us to produce maintainable features in record times, with a minimum of developers," said Cuong Do, Software Architect, YouTube.com.
Industrial Light & Magic
"Python plays a key role in our production pipeline. Without it a project the size of Star Wars: Episode II would have been very difficult to pull off. From crowd rendering to batch processing to compositing, Python binds all things together," said Tommy Burnette, Senior Technical Director, Industrial Light & Magic.
"Python is everywhere at ILM. It's used to extend the capabilities of our applications, as well as providing the glue between them. Every CG image we create has involved Python somewhere in the process," said Philip Peterson, Principal Engineer, Research & Development, Industrial Light & Magic.
Google
"Python has been an important part of Google since the beginning, and remains so as the system grows and evolves. Today dozens of Google engineers use Python, and we're looking for more people with skills in this language." said Peter Norvig, director of search quality at Google, Inc.
"""

#워드클라우드
wordcloud = WordCloud(width=800, height=400, background_color='yellowgreen').generate(text)

#시각화
plt.figure(figsize=(10,5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.show()

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# 샘플 텍스트
text = """
"I swear to God I need help," said the man quietly on the other end of the line.
The Ethiopian, who calls himself Mike, said he is being held with 450 others in a building inside Myanmar, along the country's border with Thailand.
They are among the thousands of people who have been freed from the notorious scam compounds that have thrived on the border for years, in what appears to be the toughest action so far against the industry along the Thai-Myanmar border.
But many of them are now stranded in Myanmar in makeshift camps because the process of assessing them and arranging flights back to their own countries is so slow.
The armed militia groups who are holding them have a very limited capacity to support so many people – more than 7,000. One of them has said they have stopped freeing people from the compounds because they are not being moved to Thailand fast enough.
The BBC understands that conditions in the camps are unsanitary, food barely sufficient, and many of the freed workers, like Mike, are in poor health. He is suffering from panic attacks, after working for a year in a scam centre where he was routinely beaten.
He told us they got two very basic meals a day, there were only two toilets for 450 people, who he said were now relieving themselves wherever they could.
Casinos, high-rises and fraud: The BBC visits a bizarre city built on scams
The Chinese mafia's downfall in a lawless casino town
Mike described being invited a year ago to take up what he was promised would be a good job, in Thailand, requiring only good English language and typing skills.
Instead he found himself subjected to a brutal regime, forced to work long hours every day to meet the target for defrauding people online set by his Chinese bosses.
"It was the worst experience of my life. Of course I was beaten. But believe me I have seen a lot worse done to other people."
Getty Images Alleged scam centre workers and victims rest in a row. Getty Images
Those being held in the camps have complained of cramped and unsanitary conditions
Mike is one of an estimated 100,000 people who are believed to have been lured to work in the scam operations along the Thai-Myanmar border, most of them run by Chinese fraud and gambling operatives who have taken advantage of the lawlessness in this part of Myanmar.
Despite horrifying accounts of abuse from those who escaped in the past, thousands still come from parts of the world where good jobs are scarce, enticed by promises of good money.
China, where many of the scam victims come from, has acted to shut down scam operations along its own border with Myanmar, but until this year neither China nor Thailand had done much about the Thai-Myanmar border.
Ariyan, a young man from Bangladesh, has come back to Thailand to try to help 17 friends who are still there. He said he made a promise to himself to do this after his own gruelling escape from one of the most notorious scam centres last October.
He showed us a brief, shaky video of the compound, still under construction in a remote, forested valley, where he was held, and remembers the terrible treatment he and his friends suffered at the hands of their Chinese boss.
"They gave us a target every week, $5,000. If not, they gave us two electric shocks. Or they put us in a dark room, with no windows. But if we earned a lot of money, they were very happy with us."
Ariyan had to approach men in the Middle East and lure them into transferring funds to fictitious investments. Using AI, the scammers made him appear on the screen to be an attractive young woman, altering his voice as well.
He says he hated doing it. He remembers one man who was willing to sell his wife's jewellery to fund the fraudulent investment, and wishing he could warn him. But he said the bosses monitored all their calls.
"""

#워드클라우드
wordcloud = WordCloud(width=800, height=400, background_color='pink').generate(text)

#시각화
plt.figure(figsize=(10,5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.show()

# %%
## 전체를 복사해서 코파일럿에 넣어서 '친절하게 주석 달아줘~' 하면 주석도 달아준다~!

# %%
#!dir    ; 폴더 위치 확인하기 !!!

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import matplotlib.font_manager as fm
from konlpy.tag import Komoran # 명사만 분리

#한글 폰트 설정
font_path="./data ref/D2Coding-Ver1.3.2-20180524.ttf"


# 샘플 텍스트
text = """
챗지피티(Chat GPT) 개발사 오픈에이아이(AI)가 심도있는 보고서를 작성해 주는 인공지능 비서 ‘딥리서치’ 기능을 전체 유료 구독자에게 개방한다.
오픈에이아이는 25일(현지시각) 딥리서치 제공을 챗지피티 플러스(Plus)와 팀(Team), 에듀(Edu) 및 엔터프라이즈(Enterprise) 등 모든 유료 구독자에게 확대한다고 밝혔다.
오픈에이아이가 지난 3일 공개한 딥리서치는 그동안 월 이용료 200달러(약 29만원)를 내는 프로 구독자들만 쓸 수 있었다. 그러나 이번 개편으로 월 20달러(약 2만9천원)를 내는 구독자들도 이 기능을 이용할 수 있게 됐다.
광고
딥리서치는 데이터 분석 등에 최적화된 오픈에이아이의 고급 추론 모델 ‘o3’를 기반으로 구동돼 인공지능이 인터넷에서 수백개의 자료 찾아 분석·종합해 연구자 수준의 보고서를 만들 수 있다. 앞서 오픈에이아이는 딥리서치가 중국 인공지능 스타트업 딥시크의 추론 모델 ‘R1’보다 약 3배 높은 정확도를 자랑한다고 밝혔다.
플러스 구독자들은 매달 10회 딥리서치 기능을 사용할 수 있으며, 기존 프로 구독자들의 월 이용 한도는 기존 100회에서 120회로 늘었다.
"""


# data = [t for t in text if bool((t.strip()))]

komoran = Komoran()
nouns = komoran.nouns(text)
nouns_text = " ".join(nouns)
print(nouns_text)




#워드클라우드
wordcloud = WordCloud(font_path=font_path,width=800, height=400, background_color='skyblue').generate(nouns_text)

#시각화
plt.figure(figsize=(10,5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.savefig("word2.png")
plt.axis('off')  # 축 끄기.
plt.show()
# Out:
# 피 티 개발사 오픈 에 이아이 심도 보고서 작성 인공지능 비서 기능 전체 유료 구독자 개방 오픈 일 현지 시각 제공 피 티 플러스 팀 엔터프라이즈 등 유료 구독자 확대 오픈 에이 아이 일 공개 그동안 월 이용료 달러 만원 프로 구독자 수 이번 개편 월 달러 천원 구독자 기능 이용 수 광고 데이터 분석 등 최적화 오픈 에이 아이 고급 추론 모델 기반 구동 인공지능 인터넷 개 자료 분석 종합 연구자 수준 보고서 수 오픈 중국 인공지능 스타트 업 추론 모델 배 정확도 자랑 플러스 구독자 회 기능 사용 수 기존 프로 구독자 월 이용 한도 기존 회 회

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import matplotlib.font_manager as fm
from konlpy.tag import Komoran # 명사만 분리

#한글 폰트 설정
font_path="./data ref/D2Coding-Ver1.3.2-20180524.ttf"


# 샘플 텍스트
text = """
세종실록29권, 세종 7년 9월
신구 수령 교대시 각 고을에 보관된 책판을 정확히 인수 인계하게 하다
실농한 평안도·황해도 이외의 각도는 전례대로 망전·망후에 진선하게 하다
왕실 족속의 집들을 충실하게 보호하라고 함길도 감사에게 명하다
죽은 부윤 원숙이 추밀임에도 불구하고 예관을 시켜 치전하게 하다
각도의 무쇠 대장간을 대·중·소로 분별할 기준과 상납량을 정하다
혁파한 총남·천태·조계의 금은 불기·불장 등을 공조에서 수납케 하다
고 상호군 이섭에게 쌀·콩과 종이를 부의로 주다
경상좌도 주전 별감 김자양·경상우도 주전 별감 백환이 지은 돈의 수량
중외에 금주를 명하다
제주에서의 번식된 말의 많고 적음에 따라 육지에 내다 파는 가부를 결정케 하다
고의 살인한 광주의 정인수를 참형하게 하다
새로 강주 2백 채를 만들다
대언을 불러들여 정사를 보다
외직인 수령과 교관에게 과전을 예전대로 지급토록 명하다
갑진년에 국고와 의창에 수납된 2만 6백 87섬 1말의 모곡을 환자로 주게 하다
궁인에게서 왕자 이영이 출생하다
정사를 보다. 조계한 여러 신하에게 음식을 대접하다
대간 관원이 부모의 병으로 귀향한다면 계달하고 역마를 내어 주라고 전지하다
전 지울산군사 송계양의 재임중 증여죄에 대해 속전을 바치게 하다
신상·성달생·유은지·이각·성엄·이반·허성·정연 등에게 관직을 제수하다
양녕 대군에게 산 노루를 내려 주다
효령 대군 이보·공녕군 이인·근녕군 이농·의성군 이용을 불러 술자리를 베풀다
사대부 상사에 기일이 지나도록 장사지내지 않는 자를 엄하게 고찰케 하다
송골·퇴곤·보가을자 등의 매를 상납하라고 평안·함길도 감사에게 전지하다
양녕 대군에게 연어를 내려 주다
강무할 때 잡은 노루·사슴은 적당히 포육을 만들어 건두를 준비하게 하다
전 판안동대도호부사 구성량이 죽자 부의를 주다
정사를 보다
임금이 후원에서 말을 타고 병후 기력을 시험해 보다
단목을 각궁·시녀·2품 이상 대언과 경연·서연의 주서 등에게 차등있게 주다
전 지대구군사 정환을 부모상에서의 효행으로 정문을 세워 주고 복호하도록 명하다
지운산군사 원순이 재임 중 사망하자 부의하다
예조에서 올린 왕녀의 초상 장례 제도
사객을 맞이하고 보내는 역참의 정원과 부역문제에 대한 병조의 보고
예관을 보내 죽은 인수부 윤 원숙에게 사제하다
도망친 분이를 찾기 위해서 온 야인 하로통사 이도거 등이 소란을 피우다
부평 고을에 정역했던 시인 김맹을 석방하도록 명하다
임금의 강무 행차 계획에 대해 대신들과 의논하다
정사를 보다
임금이 악차에 거둥하여 곡파무를 구경하고 늙은 기생 봉이에게 하사품을 내리다
고려의 태조·현종·문종·충경왕은 종전대로 제사를 모시라고 교지하다
사헌부에서 의금부의 방만한 운영의 폐해를 보고하니 논의하게 하다
동교에 행차하다
일본국 원도진과 종정성이 각각 물품을 바치다
정사를 보다
이조 판서 허조가 올린 세초할 때에 보고하여 임용하는 자료로 삼을 원칙
죽은 판부사 이화영의 어미가 경작하던 밭에서 수납하게 하다
이징·이담·이교·유사눌·고약해·성염조·정갑손 등에게 관직을 제수하다
동교에 행차하다
중국에 새해 축하로 보낼 표문에 백관이 의식대로 배례하다
포로되었던 명나라 사람 이첩목의 아내 묘진여사를 요동에서 풀어주다
양녕 대군에게 내선을 주다
단군 사당을 별도로 세우고 신위를 남향하여 제사하게 하다
충청도 도절세사가 올린 민폐를 없애는 조건
사헌부에서 정원 이상의 구사를 거느린 자들을 탄핵하니 당하관들만 처벌하게 하다
광주 지역에서 강무하다
장군 절제사 한확이 간통했다고 갈아 임명하게 하다
건지산에서 몰이하여 임금이 사슴 한 마리를 쏘다
감사 심도원이 술을 진상, 시위 군사에게 나누어 주다
"""


# data = [t for t in text if bool((t.strip()))]

komoran = Komoran()
nouns = komoran.nouns(text)
nouns_text = " ".join(nouns)
print(nouns_text)




#워드클라우드
wordcloud = WordCloud(font_path=font_path,width=800, height=400, background_color='yellow').generate(nouns_text)

#시각화
plt.figure(figsize=(10,5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.savefig("word3.png")
plt.axis('off')  # 축 끄기.
plt.show()
# Out:
# 세종실록 29 권 세종 년 9월 신구 수령 교대 시 고을 보관 책 판 인수 인계 실농 평안도 황해도 이외 각도 전례 망 전 망 후에 진 선 왕실 족속 집 충실 보호 함 길 감사 부윤 원 숙이 추밀 임 예관 치전 각도 무쇠 대장간 대 중 소 분별 기준 상납 량 혁파 남 천 태 조계 금 장 등 공조 수납 상 호군 섭 쌀 콩과 종이 부의 경상 좌 주전 별감 김 자양 경상 우도 주전 별감 백화 돈 수량 중외 금주 제주 번식 말 육지 가부 결정 고의 살인 광주 정인 수 참형 강주 채 언 정사 외직 수령 교관 전 예전 지급 갑진 년 국고 의창 수납 섬 말 모곡 환자 궁 인 왕자 이영 출생 정사 조계 신하 음식 대접 대간 관원 부모 병 귀향 계 달 역마 전지 지 울산 군사 송계 양의 재임 중 증여 죄 속전 신상 성달생 유 은지 이각 성 엄 이반 허성 정연 등 관직 제수 대군 노루 대군 이인 근녕군 이농 의성군 이용 술자리 사대부 상사 기일 장사 자 고찰 송골 퇴고 보 가을 자 등 매 상납 평안 함 길 감사 전지 대군 연어 강 무 때 노루 사슴 포 육 건 준비 판 안동 대도호부 사 구성 량 부의 정사 임금 후원 말 병 후 기력 시험 목 각궁 시녀 품 이상 언 경연 서연 주서 등 차등 지 대구 군사 정환 부모상 효행 정문 복호 지 운산군 사 원 순이 재임 중 사망 부의 예조 왕녀 초상 장례 제도 사 객 역 참의 정원 부역 문제 병조 예관 인수 부 윤 사제 분이 야인 하 통사 도거 등 소란 부평 고을 정역 시인 김 석방 임금 강 무 행차 계획 대신 의논 정사 임금 악 차 거 둥 곡 파 무 구경 기생 봉 이 하사 품 고려 태조 현종 문종 충 경왕 종전 제사 교지 사헌부 의금부 운영 폐해 보고 논의 동교 행차 일본국 원도 진 종정 물품 정사 이조 판서 허조 초 때 보고 임용 자료 원칙 판 부사 이화영 어미 경작 밭 수납 이징 이담 이교 유사 누 성염 조 정 갑 손 등 관직 제수 동교 행차 중국 새해 축하 표 문 관이 의식 배례 포로 명나라 사람 이첩 목 아내 묘진 여사 요동 대군 내선 단군 사당 별도 신위 남향 제사 충청도 도절 세사 민폐 조건 사헌부 정원 이상 구사 자 탄핵 하니 당하관 처벌 광주 지역 강 무 장군 절 제사 한확 간통 임명 건지산 몰이 임금 사슴 마리 감사 심도원 술 진상 시위 군사

# %%
from collections import Counter
word_counts = Counter(nouns_text.split())
print(word_counts)
# Out:
# Counter({'등': 6, '정사': 5, '대군': 4, '무': 4, '임금': 4, '판': 3, '감사': 3, '중': 3, '수납': 3, '부의': 3, '말': 3, '지': 3, '군사': 3, '자': 3, '강': 3, '사': 3, '행차': 3, '제사': 3, '년': 2, '수령': 2, '고을': 2, '인수': 2, '각도': 2, '망': 2, '전': 2, '진': 2, '함': 2, '길': 2, '원': 2, '예관': 2, '상납': 2, '량': 2, '조계': 2, '경상': 2, '주전': 2, '별감': 2, '김': 2, '광주': 2, '언': 2, '병': 2, '전지': 2, '재임': 2, '관직': 2, '제수': 2, '노루': 2, '때': 2, '사슴': 2, '목': 2, '품': 2, '이상': 2, '정원': 2, '사헌부': 2, '보고': 2, '동교': 2, '세종실록': 1, '29': 1, '권': 1, '세종': 1, '9월': 1, '신구': 1, '교대': 1, '시': 1, '보관': 1, '책': 1, '인계': 1, '실농': 1, '평안도': 1, '황해도': 1, '이외': 1, '전례': 1, '후에': 1, '선': 1, '왕실': 1, '족속': 1, '집': 1, '충실': 1, '보호': 1, '부윤': 1, '숙이': 1, '추밀': 1, '임': 1, '치전': 1, '무쇠': 1, '대장간': 1, '대': 1, '소': 1, '분별': 1, '기준': 1, '혁파': 1, '남': 1, '천': 1, '태': 1, '금': 1, '장': 1, '공조': 1, '상': 1, '호군': 1, '섭': 1, '쌀': 1, '콩과': 1, '종이': 1, '좌': 1, '자양': 1, '우도': 1, '백화': 1, '돈': 1, '수량': 1, '중외': 1, '금주': 1, '제주': 1, '번식': 1, '육지': 1, '가부': 1, '결정': 1, '고의': 1, '살인': 1, '정인': 1, '수': 1, '참형': 1, '강주': 1, '채': 1, '외직': 1, '교관': 1, '예전': 1, '지급': 1, '갑진': 1, '국고': 1, '의창': 1, '섬': 1, '모곡': 1, '환자': 1, '궁': 1, '인': 1, '왕자': 1, '이영': 1, '출생': 1, '신하': 1, '음식': 1, '대접': 1, '대간': 1, '관원': 1, '부모': 1, '귀향': 1, '계': 1, '달': 1, '역마': 1, '울산': 1, '송계': 1, '양의': 1, '증여': 1, '죄': 1, '속전': 1, '신상': 1, '성달생': 1, '유': 1, '은지': 1, '이각': 1, '성': 1, '엄': 1, '이반': 1, '허성': 1, '정연': 1, '이인': 1, '근녕군': 1, '이농': 1, '의성군': 1, '이용': 1, '술자리': 1, '사대부': 1, '상사': 1, '기일': 1, '장사': 1, '고찰': 1, '송골': 1, '퇴고': 1, '보': 1, '가을': 1, '매': 1, '평안': 1, '연어': 1, '포': 1, '육': 1, '건': 1, '준비': 1, '안동': 1, '대도호부': 1, '구성': 1, '후원': 1, '후': 1, '기력': 1, '시험': 1, '각궁': 1, '시녀': 1, '경연': 1, '서연': 1, '주서': 1, '차등': 1, '대구': 1, '정환': 1, '부모상': 1, '효행': 1, '정문': 1, '복호': 1, '운산군': 1, '순이': 1, '사망': 1, '예조': 1, '왕녀': 1, '초상': 1, '장례': 1, '제도': 1, '객': 1, '역': 1, '참의': 1, '부역': 1, '문제': 1, '병조': 1, '부': 1, '윤': 1, '사제': 1, '분이': 1, '야인': 1, '하': 1, '통사': 1, '도거': 1, '소란': 1, '부평': 1, '정역': 1, '시인': 1, '석방': 1, '계획': 1, '대신': 1, '의논': 1, '악': 1, '차': 1, '거': 1, '둥': 1, '곡': 1, '파': 1, '구경': 1, '기생': 1, '봉': 1, '이': 1, '하사': 1, '고려': 1, '태조': 1, '현종': 1, '문종': 1, '충': 1, '경왕': 1, '종전': 1, '교지': 1, '의금부': 1, '운영': 1, '폐해': 1, '논의': 1, '일본국': 1, '원도': 1, '종정': 1, '물품': 1, '이조': 1, '판서': 1, '허조': 1, '초': 1, '임용': 1, '자료': 1, '원칙': 1, '부사': 1, '이화영': 1, '어미': 1, '경작': 1, '밭': 1, '이징': 1, '이담': 1, '이교': 1, '유사': 1, '누': 1, '성염': 1, '조': 1, '정': 1, '갑': 1, '손': 1, '중국': 1, '새해': 1, '축하': 1, '표': 1, '문': 1, '관이': 1, '의식': 1, '배례': 1, '포로': 1, '명나라': 1, '사람': 1, '이첩': 1, '아내': 1, '묘진': 1, '여사': 1, '요동': 1, '내선': 1, '단군': 1, '사당': 1, '별도': 1, '신위': 1, '남향': 1, '충청도': 1, '도절': 1, '세사': 1, '민폐': 1, '조건': 1, '구사': 1, '탄핵': 1, '하니': 1, '당하관': 1, '처벌': 1, '지역': 1, '장군': 1, '절': 1, '한확': 1, '간통': 1, '임명': 1, '건지산': 1, '몰이': 1, '마리': 1, '심도원': 1, '술': 1, '진상': 1, '시위': 1})

# %% [markdown]
# - 내일 점심 전까지 : 팀별로 적당한 주제를 선정하여 (소설,영화,실록,뉴스 ...)
# - 워드 카운트(분석카운트) / 워드클라우드(시각화)

# %% [markdown]
# <팀 도 전 과 제>
#
# - 우리가 직접 코드를 작성해서 입력받은 문자 속에서 단어가 몇 번 등장했는지
# - 세는 하드코딩을 ....해보자...... 왜(Why)?
# - 추가 2 : 검증 프로그램 제작 > 작성한 워드카운터 프로그램이 collections와 비교하여 일치하는지 여부 판단
